# %% [markdown]
# ### Задание 1.1.1

# %%
import math

class Tmath:
    
    def sin(self, n):
        return math.sin(n)
    
    def cos(self, n):
        return math.cos(n)
    
    def tan(self, n):
        return math.tan(n)
    
    def arcsin(self, n):
        return math.sinh(n)
    
    def arccos(self, n):
        return math.cosh(n)
    
    def arctan(self, n):
        return math.tanh(n)
    
    def radians(self, n):
        return math.radians(n)
    
t = Tmath()

print(t.sin(50))
print(t.cos(30))
print(t.tan(80))
print(t.arcsin(30))
print(t.arccos(45))
print(t.arctan(45))
print(t.radians(90))
# Out:
# -0.26237485370392877
# 0.15425144988758405
# 9.00365494560708
# 5343237290762.231
# 1.7467135528742547e+19
# 1.0
# 1.5707963267948966

# %% [markdown]
# ### Задание 1.2.1

# %%
class Tree:
    def __init__(self, name, left = None, right = None):
        self.name = name
        self.left = left
        self.right = right

t = Tree('a', Tree('b', Tree('d'), Tree('e')), Tree('c', Tree('f')))
print(f'      {t.name}    ')
print(f'     / \    ')
print(f'    {t.left.name}   {t.right.name}')
print(f'   / \  |')
print(f'  {t.left.left.name}   {t.left.right.name} {t.right.left.name}')
# Out:
#       a
#      / \
#     b   c
#    / \  |
#   d   e f

# %% [markdown]
# ### Задание 1.2.2

# %%
class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def push(self, value):
        if value < self.data:
            if self.left is None:
                self.left = Tree(value)
            else:
                self.left.push(value)
                
        elif value > self.data:
            if self.right is None:
                self.right = Tree(value)
            else:
                self.right.push(value)

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print(self.data)
        if self.right:
            self.right.PrintTree()
            
t = Tree(10)
t.push(5)
t.push(15)
t.push(3)
t.push(8)
t.push(34)
t.PrintTree()
# Out:
# 3
# 5
# 8
# 10
# 15
# 34

# %% [markdown]
# ### Задание 1.3.1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report, confusion_matrix

X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]]) 
target = [0, 0, 0, 1, 1, 1]

X_train, X_test, Y_train, Y_test = train_test_split(X, target, test_size=0.15)

classifier = DecisionTreeClassifier()
classifier.fit(X_train, Y_train)

tree.plot_tree(classifier)

y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0])

# %%
print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# [[1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %% [markdown]
# ## Задание 1.4.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

df = pd.read_csv('wine.csv', delimiter=',')

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(df.columns.tolist())
print(df.shape)
df.describe()
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
# (1599, 12)
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.iloc[:, -2]
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    df.iloc[:, :-2].values,
    df.iloc[:, -2].values,
    test_size=0.20,
    random_state = 0
)

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 9.5       , 11.        , 11.7       , 10.3       , 10.4       ,
#         9.1       , 10.        , 10.9       ,  9.8       ,  9.8       ,
#        10.4       , 10.2       , 10.7       , 11.4       , 10.9       ,
#        11.9       , 12.8       , 11.8       , 12.8       ,  9.6       ,
#        12.6       ,  9.5       , 10.5       , 10.1       ,  9.8       ,
#         9.05      ,  9.5       , 11.9       ,  9.5       , 12.5       ,
#        11.        , 10.2       , 10.        ,  9.2       , 12.3       ,
#        11.2       , 10.3       ,  9.4       , 13.        , 10.5       ,
#        10.5       , 11.1       , 11.5       , 13.3       , 10.1       ,
#         9.5       ,  9.6       , 11.        , 10.3       , 11.        ,
#         9.4       ,  9.2       , 10.1       , 12.7       ,  9.5       ,
#        10.1       , 11.        ,  9.4       , 12.        ,  9.2       ,
#         9.6       ,  9.4       ,  9.8       , 10.1       ,  9.4       ,
#        11.1       , 10.1       , 11.1       , 13.2       , 11.7       ,
#        10.4       ,  9.4       ,  9.6       ,  9.5       , 10.1       ,
#        11.7       ,  9.5       ,  9.4       , 10.5       , 11.9       ,
#         9.1       ,  9.        , 10.3       , 10.6       ,  9.7       ,
#         9.5       , 11.3       ,  9.6       ,  9.5       ,  9.7       ,
#         9.4       , 10.        , 11.4       , 10.5       , 11.8       ,
#        10.4       , 11.3       ,  9.5       ,  9.8       ,  9.1       ,
#        12.5       ,  9.1       ,  9.8       , 11.1       ,  9.5       ,
#         9.6       ,  9.5       , 10.2       , 11.1       ,  9.5       ,
#        11.1       ,  9.8       , 11.4       , 10.2       ,  9.8       ,
#        10.5       ,  9.8       , 12.1       , 10.2       , 10.5       ,
#         9.5       ,  9.8       , 10.1       ,  9.8       , 11.3       ,
#        10.5       ,  9.4       ,  9.2       , 11.9       , 11.4       ,
#         9.5       , 10.        , 11.9       , 11.2       , 10.1       ,
#         9.2       , 10.        , 11.8       ,  9.8       ,  9.5       ,
#        12.8       ,  9.5       ,  9.6       ,  9.7       , 10.2       ,
#         9.8       , 11.4       , 10.9       , 11.2       ,  9.2       ,
#        11.3       , 10.6       , 10.2       ,  9.55      ,  9.9       ,
#        10.9       ,  9.8       ,  9.3       , 11.8       , 11.        ,
#        11.2       , 10.4       , 11.2       ,  9.1       , 11.4       ,
#         9.8       , 10.7       , 12.        , 10.2       , 10.9       ,
#        10.4       ,  9.8       ,  9.4       , 12.5       , 10.9       ,
#        12.5       , 10.6       , 13.4       , 12.8       ,  9.2       ,
#         9.9       , 12.1       , 10.4       , 11.4       , 12.8       ,
#         9.7       ,  9.5       ,  9.8       ,  9.9       , 10.6       ,
#        11.1       , 11.2       , 10.3       ,  9.2       ,  9.5       ,
#         9.4       , 10.4       , 10.5       ,  9.1       ,  9.4       ,
#         9.4       , 11.1       ,  9.8       ,  9.55      , 10.5       ,
#         9.8       ,  9.        , 11.9       ,  9.        ,  9.5       ,
#        11.6       , 10.55      ,  9.1       ,  9.4       , 10.8       ,
#         9.9       ,  9.1       , 10.6       , 10.3       , 10.2       ,
#         9.4       , 11.6       , 13.4       ,  9.1       , 10.3       ,
#         9.6       , 11.2       , 10.5       ,  9.6       ,  9.4       ,
#         9.7       , 11.7       ,  9.5       ,  9.5       , 10.9       ,
#        10.7       , 11.3       , 10.5       , 12.8       , 11.4       ,
#         9.8       , 11.        ,  9.4       ,  9.4       , 10.2       ,
#         9.2       ,  9.3       , 10.1       ,  9.2       , 11.8       ,
#         9.5       , 10.7       , 11.4       ,  9.6       , 10.        ,
#         9.8       ,  9.9       ,  9.3       ,  9.8       , 10.        ,
#         9.2       , 14.        , 10.2       ,  9.3       , 10.        ,
#        10.4       , 11.9       ,  9.2       ,  9.3       , 11.        ,
#        10.4       ,  9.5       , 12.1       , 12.5       , 13.4       ,
#        10.3       , 11.        ,  9.5       , 12.8       , 11.8       ,
#         9.4       , 10.9       ,  9.5       , 12.        ,  9.6       ,
#         9.8       , 10.1       ,  9.8       , 11.2       ,  9.9       ,
#        10.4       , 11.9       , 10.3       ,  9.5       ,  9.58333333,
#        11.3       , 10.1       ,  9.2       ,  9.3       ,  9.4       ,
#        11.3       , 10.8       ,  9.3       , 10.1       , 11.2       ,
#        11.4       , 10.7       ,  9.3       ,  9.2       ,  9.4       ,
#        11.        , 11.        ,  9.8       ,  9.5       , 10.4       ,
#        13.4       , 11.5       , 12.3       , 11.        , 12.1       ])

# %%
compare = pd.DataFrame({'Actual' : Y_test, 'Predicted' : y_pred})
compare
# Out:
#      Actual  Predicted
# 0      10.8        9.5
# 1       9.6       11.0
# 2      11.7       11.7
# 3      10.0       10.3
# 4      10.4       10.4
# ..      ...        ...
# 315    12.5       13.4
# 316    11.4       11.5
# 317    11.4       12.3
# 318     9.7       11.0
# 319    12.3       12.1
#
# [320 rows x 2 columns]

# %%
from sklearn import metrics
print('MSE', metrics.mean_squared_error(Y_test, y_pred))
print('MAE', metrics.mean_absolute_error(Y_test, y_pred))
# Out:
# MSE 0.4843888888888889
# MAE 0.43739583333333343
